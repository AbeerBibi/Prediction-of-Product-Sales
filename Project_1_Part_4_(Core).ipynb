# %% [markdown]
# <a href="https://colab.research.google.com/github/AbeerBibi/Prediction-of-Product-Sales/blob/main/Project_1_Part_4_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
path="/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/sales_prediction_cleaned.csv"
df_sales = pd.read_csv(path)
df_sales.head(50)
# Out:
#     Unnamed: 0 Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            0           FDA15        9.300          Low Fat         0.016047
# 1            1           DRC01        5.920          Regular         0.019278
# 2            2           FDN15       17.500          Low Fat         0.016760
# 3            3           FDX07       19.200          Regular         0.000000
# 4            4           NCD19        8.930          Low Fat         0.000000
# 5            5           FDP36       10.395          Regular         0.000000
# 6            6           FDO10       13.650          Regular         0.012741
# 7            7           FDP10       -1.000          Low Fat         0.127470
# 8            8           FDH17       16.200          Regular         0.016687
# 9            9           FDU28       19.200          Regular         0.094450
# 10          10           FDY07       11.800          Low Fat         0.000000
# ...

# %% [markdown]
# #Remove the placeholders you added in week 2 and replace them with null values.

# %%
# Replace -1 with null for 'Item_Weight'
df_sales['Item_Weight'] = df_sales['Item_Weight'].replace(-1, np.nan)

# Replace 'MISSING' with null for 'Outlet_Size'
df_sales['Outlet_Size'] = df_sales['Outlet_Size'].replace('MISSING', np.nan)

# %%
df_sales.head(50)
# Out:
#     Unnamed: 0 Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            0           FDA15        9.300          Low Fat         0.016047
# 1            1           DRC01        5.920          Regular         0.019278
# 2            2           FDN15       17.500          Low Fat         0.016760
# 3            3           FDX07       19.200          Regular         0.000000
# 4            4           NCD19        8.930          Low Fat         0.000000
# 5            5           FDP36       10.395          Regular         0.000000
# 6            6           FDO10       13.650          Regular         0.012741
# 7            7           FDP10          NaN          Low Fat         0.127470
# 8            8           FDH17       16.200          Regular         0.016687
# 9            9           FDU28       19.200          Regular         0.094450
# 10          10           FDY07       11.800          Low Fat         0.000000
# ...

# %% [markdown]
# #I'll incorporate the functions needed for the code, then proceed to explore the features and address the questions.

# %% [markdown]
# ##_Univariate (numeric) Plotting Functions For EDA

# %%
def explore_numeric(df, x, figsize=(6,5) ):
  """Creates a seaborn histplot and boxplot with a share x-axis,
  Prints statements about null values, cardinality, and checks for
  constant/quasi-constant features.
  """

  ## Save null value counts and percent for printing
  null_count = df[x].isna().sum()
  null_perc = null_count/len(df)* 100


  ## Making our figure with gridspec for subplots
  gridspec = {'height_ratios':[0.7,0.3]}
  fig, axes = plt.subplots(nrows=2, figsize=figsize,
                           sharex=True, gridspec_kw=gridspec)
  # Histogram on Top
  sns.histplot(data=df, x=x, ax=axes[0])

  # Boxplot on Bottom
  sns.boxplot(data=df, x=x, ax=axes[1])

  ## Adding a title
  axes[0].set_title(f"Column: {x}", fontweight='bold')

  ## Adjusting subplots to best fill Figure
  fig.tight_layout()

  # Ensure plot is shown before message
  plt.show()


  # Print null value info
  print(f"- NaN's Found: {null_count} ({round(null_perc,2)}%)")
  # Print cardinality info
  nunique = df[x].nunique()
  print(f"- Unique Values: {nunique}")


  # Get the most most common value, its count as # and as %
  most_common_val_count = df[x].value_counts(dropna=False).head(1)
  most_common_val = most_common_val_count.index[0]
  freq = most_common_val_count.values[0]
  perc_most_common = freq / len(df) * 100

  print(f"- Most common value: '{most_common_val}' occurs {freq} times ({round(perc_most_common,2)}%)")

  # print message if quasi-constant or constant (most common val more than 98% of data)
  if perc_most_common > 98:
    print(f"\n- [!] Warning: '{x}' is a constant or quasi-constant feature and should be dropped.")
  else:
    print("- Not constant or quasi-constant.")
  return fig, axes

# %% [markdown]
# ##Univariate (categery) Plotting Functions For  EDA

# %%
"""UNIVARIATE PLOTTING FUNCTIONS FOR EDA"""
# Add the print statements to the function
def explore_categorical(df, x, fillna = True, placeholder = 'MISSING',
                        figsize = (6,4), order = None):
  """Creates a seaborn countplot with the option to temporarily fill missing values
  Prints statements about null values, cardinality, and checks for
  constant/quasi-constant features.
  """
  # Make a copy of the dataframe and fillna
  temp_df = df.copy()
  # Before filling nulls, save null value counts and percent for printing
  null_count = temp_df[x].isna().sum()
  null_perc = null_count/len(temp_df)* 100
  # fillna with placeholder
  if fillna == True:
    temp_df[x] = temp_df[x].fillna(placeholder)
  # Create figure with desired figsize
  fig, ax = plt.subplots(figsize=figsize)
  # Plotting a count plot
  sns.countplot(data=temp_df, x=x, ax=ax, order=order)
  # Rotate Tick Labels for long names
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
  # Add a title with the feature name included
  ax.set_title(f"Column: {x}", fontweight='bold')

  # Fix layout and show plot (before print statements)
  fig.tight_layout()
  plt.show()

  # Print null value info
  print(f"- NaN's Found: {null_count} ({round(null_perc,2)}%)")
  # Print cardinality info
  nunique = temp_df[x].nunique()
  print(f"- Unique Values: {nunique}")
  # First find value counts of feature
  val_counts = temp_df[x].value_counts(dropna=False)
  # Define the most common value
  most_common_val = val_counts.index[0]
  # Define the frequency of the most common value
  freq = val_counts.values[0]
  # Calculate the percentage of the most common value
  perc_most_common = freq / len(temp_df) * 100
  # Print the results
  print(f"- Most common value: '{most_common_val}' occurs {freq} times ({round(perc_most_common,2)}%)")
  # print message if quasi-constant or constant (most common val more than 98% of data)
  if perc_most_common > 98:
    print(f"\n- [!] Warning: '{x}' is a constant or quasi-constant feature and should be dropped.")
  else:
    print("- Not constant or quasi-constant.")
  return fig, ax

# %% [markdown]
# ##_Multivariate Plotting Functions Numeric VS. Numeric Target

# %%
def plot_numeric_vs_target(df, x, y,
                           figsize=(6,4),
                           ):
  """Plots a seaborn regplot with Pearson's correlation (r) added
  to the title.
  Source:{PASTE IN FINAL LESSON LINK}
  """
  # Calculate the correlation
  corr = df[[x,y]].corr().round(2)
  r = corr.loc[x,y]

  # Plot the data
  fig, ax = plt.subplots(figsize=figsize)
  scatter_kws={'ec':'white','lw':1,'alpha':0.8}
  sns.regplot(data=df, x=x, y=y, ax=ax, scatter_kws=scatter_kws)

  ## Add the title with the correlation
  ax.set_title(f"{x} vs. {y} (r = {r})", fontweight='bold')

  # Make sure the plot is shown before the print statement
  plt.show()

  return fig, ax

# %% [markdown]
# ##_Multivariate Plotting Functions Categorical VS. Numeric Target

# %%
def plot_categorical_vs_target(df, x, y,figsize=(6,4),
                            fillna = True, placeholder = 'MISSING',
                            order = None):
  """Plots a combination of a seaborn barplot of means combined with
  a seaborn stripplot to show the spread of the data.
  Source:{PASTE IN FINAL LESSON LINK}
  """
  # Make a copy of the dataframe and fillna
  temp_df = df.copy()
  # fillna with placeholder
  if fillna == True:
    temp_df[x] = temp_df[x].fillna(placeholder)

  # or drop nulls prevent unwanted 'nan' group in stripplot
  else:
    temp_df = temp_df.dropna(subset=[x])
  # Create the figure and subplots
  fig, ax = plt.subplots(figsize=figsize)

    # Barplot
  sns.barplot(data=temp_df, x=x, y=y, ax=ax, order=order, alpha=0.6,
              linewidth=1, edgecolor='black', errorbar=None)

  # Boxplot
  sns.stripplot(data=temp_df, x=x, y=y, hue=x, ax=ax,
                order=order, hue_order=order, legend=False,
                edgecolor='white', linewidth=0.5,
                size=3,zorder=0)
  # Rotate xlabels
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

  # Add a title
  ax.set_title(f"{x} vs. {y}", fontweight='bold')
  fig.tight_layout()
  return fig, ax

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %% [markdown]
# #Our target to predict is (Item_Outlet_Sales):Sales of the product in the particular store (numeric target).

# %%
df_sales['Item_Outlet_Sales'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #We will now start exploring features. I will explore:
# 1. Item_Weight:
#  - Weight of product
# 2. Item_Fat_Content:
#  - Whether the product is low-fat or regular
# 3. Item_MRP:
#  - Maximum Retail Price (list price) of the product
# 4. Outlet_Location_Type:
#  - The type of area in which the store is located
# 5. Outlet_Size:
#  - The size of the store in terms of ground area covered

# %%
df_sales.dtypes
# Out:
# Unnamed: 0                     int64
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# #A) Item Weight: numeric feature

# %% [markdown]
# ##1)Create a univariate visualization showing the distribution of values

# %%
feature1="Item_Weight"
explore_numeric(df_sales, feature1);
# Out:
# - NaN's Found: 1463 (17.17%)
# - Unique Values: 415
# - Most common value: 'nan' occurs 1463 times (17.17%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##2) Feature Observation

# %% [markdown]
# - What type of feature is it? (Categorical (nominal), ordinal, numeric
#  - Float.
# - How many null values? What percentage? What would you do with the null values (drop the rows? drop the column? impute? if impute, with what?)
#  - 1463 null values (17.17%). Will replace by the average.
# - Is the feature constant or quasi-constant?
#  - No, the most common value only occurs in 17.17% of the values. The threshold for quasi-constant is more than 98%.
# - What is the cardinality? Is it high?
#  - There are 415 unique values. This is more than 10, which is our threshold for high cardinality. So, it is very high cardinality.
# - Would we know this BEFORE the target is determined?
#  - Yes.
# - Is there a business case/understanding reason to exclude based on our business case?
#  - Yes, the weight is something controlled by the manufacturer not the seller. Below, in the univeriant plot, it also shows that there is no correlation with the sale price+ high cardinality

# %% [markdown]
# replace the nulls with the average:

# %%
# Replace null values in the 'Item_Weight' column with the mean
df_sales['Item_Weight'].fillna(df_sales['Item_Weight'].mean(), inplace=True)
df_sales['Item_Weight'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##3) Multivariate Viz

# %%
plot_numeric_vs_target(df_sales, feature1, 'Item_Outlet_Sales' )
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Item_Weight vs. Item_Outlet_Sales (r = 0.01)'}, xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>)

# %% [markdown]
# ##4) Feature vs. Target Observations
# - Based on your business understanding, would you expect this feature to be a predictor of the target?
#  - for me, I would think the weight for some goods, will affect the sales. Like: buying family size of vegatable oil will be chaeper than the less size, and will stay longer, so I thought (before plotting) that the size will affect. Anyways, it is random, based on the product itself as well.
# - Does this feature appear to be a predictor of the target?
#  - No.

# %% [markdown]
# #B) Item_Fat_Content

# %% [markdown]
# ##1)Create a univariate visualization showing the distribution of values

# %%
feature2="Item_Fat_Content"
explore_categorical(df_sales, feature2);
# Out:
# <ipython-input-6-bc46dae8aa0f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# - NaN's Found: 0 (0.0%)
# - Unique Values: 5
# - Most common value: 'Low Fat' occurs 5089 times (59.71%)
# - Not constant or quasi-constant.

# %% [markdown]
# We've identified inconsistencies that need to be addressed by standardizing all occurrences of "low fat" to "Low Fat" and all instances of "regular" to "Regular."

# %%
df_sales['Item_Fat_Content'].replace({'LF': 'Low Fat', 'low fat': 'Low Fat'}, inplace=True)
df_sales['Item_Fat_Content'].replace({'reg': 'Regular'}, inplace=True)

# %% [markdown]
# will plot again now:

# %%
explore_categorical(df_sales, feature2);
# Out:
# <ipython-input-6-bc46dae8aa0f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# - NaN's Found: 0 (0.0%)
# - Unique Values: 2
# - Most common value: 'Low Fat' occurs 5517 times (64.73%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##2) Feature Observation

# %% [markdown]
# - What type of feature is it? (Categorical (nominal), ordinal, numeric
#  - Object
# - How many null values? What percentage? What would you do with the null values (drop the rows? drop the column? impute? if impute, with what?)
#  - zero.
# - Is the feature constant or quasi-constant?
#  - No, the most common value only occurs in 64.73% of the values. The threshold for quasi-constant is more than 98%.
# - What is the cardinality? Is it high?
#  - There are 2 unique values. This is less than 10, which is our threshold for high cardinality. So, it is low cardinality.
# - Would we know this BEFORE the target is determined?
#  - Yes.
# - Is there a business case/understanding reason to exclude based on our business case?
# - No, I believe people tend to buy the low fat products as they are healthier.

# %% [markdown]
# ##3) Multivariate Viz

# %%
plot_categorical_vs_target(df_sales, feature2, 'Item_Outlet_Sales' )
# Out:
# <ipython-input-8-945b7950c10b>:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Item_Fat_Content vs. Item_Outlet_Sales'}, xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>)

# %% [markdown]
# ##4) Feature vs. Target Observations
# - Based on your business understanding, would you expect this feature to be a predictor of the target?
#  - As mentioned above, for me, I would think the weight for some goods, will affect the sales. Like: buying family size of vegatable oil will be chaeper than the less size, and will stay longer, so I thought (before plotting) that the size will affect. Anyways, it is random, based on the product itself as well.
# - Does this feature appear to be a predictor of the target?
#  - Not really, the varience of sales between the regular and low fat, is not really much, if considered. So, looks from the plot above that this feature will not affect the sale-price.

# %% [markdown]
# #B) Item_MRP

# %% [markdown]
# ##1)Create a univariate visualization showing the distribution of values

# %%
feature3="Item_MRP"
explore_numeric(df_sales, feature3);
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 5938
# - Most common value: '172.0422' occurs 7 times (0.08%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##2) Feature Observation

# %% [markdown]
# - What type of feature is it? (Categorical (nominal), ordinal, numeric
#  - Float.
# - How many null values? What percentage? What would you do with the null values (drop the rows? drop the column? impute? if impute, with what?)
#  - zero
# - Is the feature constant or quasi-constant?
#  - No, the most common value only occurs in 0.08% of the values. The threshold for quasi-constant is more than 98%.
# - What is the cardinality? Is it high?
#  - There are 5938 unique values. This is more than 10, which is our threshold for high cardinality. So, it is very high cardinality.
# - Would we know this BEFORE the target is determined?
#  - Yes.
# - Is there a business case/understanding reason to exclude based on our business case?
#  - Yes, the cardinality is so high so it will be excluded from our model.

# %% [markdown]
# ##3) Multivariate Viz

# %%
plot_numeric_vs_target(df_sales, feature3, 'Item_Outlet_Sales' )
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Item_MRP vs. Item_Outlet_Sales (r = 0.57)'}, xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>)

# %% [markdown]
# ##4) Feature vs. Target Observations
# - Based on your business understanding, would you expect this feature to be a predictor of the target?
#  - yes, I believe if the prices are affordable, the sales will be higher for any product.
# - Does this feature appear to be a predictor of the target?
#  - From the plot above, looks yes, there is a positive correlation. But based on the value cardinality, we will exclude this feature from the model.

# %% [markdown]
# # D) Outlet_Location_Type

# %% [markdown]
# ##1)Create a univariate visualization showing the distribution of values

# %%
feature4="Outlet_Location_Type"
explore_categorical(df_sales, feature4);
# Out:
# <ipython-input-6-bc46dae8aa0f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# - NaN's Found: 0 (0.0%)
# - Unique Values: 3
# - Most common value: 'Tier 3' occurs 3350 times (39.31%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##2) Feature Observation

# %% [markdown]
# - What type of feature is it? (Categorical (nominal), ordinal, numeric
#  - Object.
# - How many null values? What percentage? What would you do with the null values (drop the rows? drop the column? impute? if impute, with what?)
#  - zero
# - Is the feature constant or quasi-constant?
#  - No, the most common value only occurs in 39.31% of the values. The threshold for quasi-constant is more than 98%.
# - What is the cardinality? Is it high?
#  - There are 3 unique values. This is less than 10, which is our threshold for high cardinality. So, it is low cardinality.
# - Would we know this BEFORE the target is determined?
#  - Yes.
# - Is there a business case/understanding reason to exclude based on our business case?
#  - No.

# %% [markdown]
# ##3) Multivariate Viz

# %%
plot_categorical_vs_target(df_sales, feature4, 'Item_Outlet_Sales' )
# Out:
# <ipython-input-8-945b7950c10b>:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Outlet_Location_Type vs. Item_Outlet_Sales'}, xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>)

# %% [markdown]
# ##4) Feature vs. Target Observations
# - Based on your business understanding, would you expect this feature to be a predictor of the target?
#  - yes, I believe if the store locates in the city center for example, I assume the sales will be higher as the location is vital
# - Does this feature appear to be a predictor of the target?
#  - From the plot above, looks yes, tier 3 has the highest sales then 2 then 1.

# %% [markdown]
# #E)Outlet_Size

# %% [markdown]
# ##1)Create a univariate visualization showing the distribution of values

# %%
feature5="Outlet_Size"
explore_categorical(df_sales, feature5);
# Out:
# <ipython-input-6-bc46dae8aa0f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# - NaN's Found: 2410 (28.28%)
# - Unique Values: 4
# - Most common value: 'Medium' occurs 2793 times (32.77%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##2) Feature Observation

# %% [markdown]
# - What type of feature is it? (Categorical (nominal), ordinal, numeric
#  - Object.
# - How many null values? What percentage? What would you do with the null values (drop the rows? drop the column? impute? if impute, with what?)
#  - 2410
# - Is the feature constant or quasi-constant?
#  - No, the most common value only occurs in 32.77% of the values. The threshold for quasi-constant is more than 98%.
# - What is the cardinality? Is it high?
#  - There are 4 unique values. This is less than 10, which is our threshold for high cardinality. So, it is low cardinality.
# - Would we know this BEFORE the target is determined?
#  - Yes.
# - Is there a business case/understanding reason to exclude based on our business case?
#  - No.

# %% [markdown]
# ###need to check the type of the store when nan size, cause we have a lot of missings in the area.

# %%
check_col=['Outlet_Location_Type', 'Outlet_Size', 'Outlet_Type', 'Outlet_Establishment_Year']

## Save filter of null size
filter_null_size = df_sales['Outlet_Size'].isna()

## Filter the lot columsn for rows missing lot frontage
check = df_sales.loc[filter_null_size, check_col]
check
# Out:
#      Outlet_Location_Type Outlet_Size        Outlet_Type  \
# 3                  Tier 3         NaN      Grocery Store
# 8                  Tier 2         NaN  Supermarket Type1
# 9                  Tier 2         NaN  Supermarket Type1
# 25                 Tier 2         NaN  Supermarket Type1
# 28                 Tier 3         NaN      Grocery Store
# ...                   ...         ...                ...
# 8502               Tier 2         NaN  Supermarket Type1
# 8508               Tier 2         NaN  Supermarket Type1
# 8509               Tier 3         NaN      Grocery Store
# 8514               Tier 2         NaN  Supermarket Type1
# 8519               Tier 2         NaN  Supermarket Type1
#
#       Outlet_Establishment_Year
# 3                          1998
# 8                          2002
# 9                          2007
# 25                         2007
# 28                         1998
# ...                         ...
# 8502                       2002
# ...

# %%
#see which location has more mnull values
checklocationnull_df = check.groupby(['Outlet_Location_Type', 'Outlet_Type', 'Outlet_Establishment_Year'])['Outlet_Size'].value_counts(dropna=False)
checklocationnull_df
# Out:
# Outlet_Location_Type  Outlet_Type        Outlet_Establishment_Year  Outlet_Size
# Tier 2                Supermarket Type1  2002                       NaN            929
#                                          2007                       NaN            926
# Tier 3                Grocery Store      1998                       NaN            555
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# ###So, highest missing is in Supermarket Type1, Tier 2, year 2002 more nulls than 2007. And we have 555 nulls in grocery store, tier 3, year 1998. So, I would drop the nulls since there is no correlation between the null distrubution.

# %%
df_sales.dropna(subset=['Outlet_Size'], inplace=True)

# %%
#I want to plot again now:
feature5="Outlet_Size"
explore_categorical(df_sales, feature5);
# Out:
# <ipython-input-6-bc46dae8aa0f>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# - NaN's Found: 0 (0.0%)
# - Unique Values: 3
# - Most common value: 'Medium' occurs 2793 times (45.69%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##3) Multivariate Viz

# %%
plot_categorical_vs_target(df_sales, feature5, 'Item_Outlet_Sales' )
# Out:
# <ipython-input-8-945b7950c10b>:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Outlet_Size vs. Item_Outlet_Sales'}, xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>)

# %% [markdown]
# ##4) Feature vs. Target Observations
# - Based on your business understanding, would you expect this feature to be a predictor of the target?
#  - yes, the larger the store, the more variety of products, and higher sales.
# - Does this feature appear to be a predictor of the target?
#  - Yes, but not as I expected, the medium has more sales that high and small outlet size
